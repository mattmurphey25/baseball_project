# %%
import pandas as pd

# %%
df = pd.read_csv(f"Resources/full_draft_prediction_OvPck.csv")
df.head()
# Out:
#    Unnamed: 0                     Name  OvPck  Pos  Rnd  ST      Tm Type  WAR  \
# 0        2015     Taylor Ward (minors)     26    C    1  CA  Angels  4Yr  0.0
# 1        2016    Jahmai Jones (minors)     70   OF    2  GA  Angels   HS  0.0
# 2        2017    Grayson Long (minors)    104  RHP    3  TX  Angels  4Yr  0.0
# 3        2018  Brendon Sanger (minors)    135   RF    4  FL  Angels  4Yr  0.0
# 4        2019    Jared Foster (minors)    165   RF    5  LA  Angels  4Yr  0.0
#
#   WAR_prediction
# 0         NO WAR
# 1         NO WAR
# 2         NO WAR
# 3         NO WAR
# 4         NO WAR

# %%
df[['Name','Last Name']] = df['Name'].str.split('(',expand=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f4a34e1ab8ec> in <module>()
# ----> 1 df[['Name','Last Name']] = df['Name'].str.split(' ',expand=True)
#       2 df.head()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2512
#    2513         if isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2514             self._setitem_array(key, value)
#    2515         elif isinstance(key, DataFrame):
#    2516             self._setitem_frame(key, value)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2536             if isinstance(value, DataFrame):
#    2537                 if len(value.columns) != len(key):
# -> 2538                     raise ValueError('Columns must be same length as key')
# ...

# %%
del df["Unnamed: 0"]
del df["Last Name"]
df.head()
# Out:
#               Name  OvPck  Pos  Rnd  ST      Tm Type  WAR WAR_prediction
# 0     Taylor Ward      26    C    1  CA  Angels  4Yr  0.0         NO WAR
# 1    Jahmai Jones      70   OF    2  GA  Angels   HS  0.0         NO WAR
# 2    Grayson Long     104  RHP    3  TX  Angels  4Yr  0.0         NO WAR
# 3  Brendon Sanger     135   RF    4  FL  Angels  4Yr  0.0         NO WAR
# 4    Jared Foster     165   RF    5  LA  Angels  4Yr  0.0         NO WAR

# %%
df.to_csv("Resources/full_draft_prediction_OvPck_edit.csv")
