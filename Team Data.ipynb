# %%
import pandas as pd

# %%
team_id = "BOS"
url = f"https://www.baseball-reference.com/teams/{team_id}/"
tables = pd.read_html(url)

# %%
tables[0]
# Out:
#      Year                Tm       Lg    G    W    L  Ties   W-L%  pythW-L%  \
# 0    2018    Boston Red Sox  AL East  144   98   46     0  0.681     0.647
# 1    2017    Boston Red Sox  AL East  162   93   69     0  0.574     0.573
# 2    2016    Boston Red Sox  AL East  162   93   69     0  0.574     0.606
# 3    2015    Boston Red Sox  AL East  162   78   84     0  0.481     0.497
# 4    2014    Boston Red Sox  AL East  162   71   91     0  0.438     0.445
# 5    2013    Boston Red Sox  AL East  162   97   65     0  0.599     0.618
# 6    2012    Boston Red Sox  AL East  162   69   93     0  0.426     0.457
# 7    2011    Boston Red Sox  AL East  162   90   72     0  0.556     0.578
# 8    2010    Boston Red Sox  AL East  162   89   73     0  0.549     0.543
# 9    2009    Boston Red Sox  AL East  162   95   67     0  0.586     0.577
# 10   2008    Boston Red Sox  AL East  162   95   67     0  0.586     0.589
# ...
